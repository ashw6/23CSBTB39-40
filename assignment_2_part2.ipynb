# %% [markdown]
# <a href="https://colab.research.google.com/github/ashw6/23CSBTB39-40/blob/main/assignment_2_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Dataset
people = ['sathwika', 'chinni', 'chinnu', 'assu']
age = [25, 30, 35, 40]
height = [145, 151, 165, 173]
weight = [45, 55, 65, 75]

# %%
# Bar Chart
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.bar(people, weight, color='green')

# Adding Titles and Labels
plt.title('Weight of Individuals')
plt.xlabel('Person')
plt.ylabel('Weight (kg)')

# Display Plot
plt.show()

# %%
# Histogram
plt.figure(figsize=(10, 6))
plt.hist(age, bins=4, color='orange', edgecolor='black')

# Adding Titles and Labels
plt.title('Distribution of Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')

# Display Plot
plt.show()
