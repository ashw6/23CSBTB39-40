# %% [markdown]
# <a href="https://colab.research.google.com/github/ashw6/23CSBTB39-40/blob/main/2303A52089%5BAssignment_week_4%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
df = pd.read_csv('housing (1).csv')
print(df.dtypes)
summary = df.describe(percentiles=[.25, .5, .75, .90])
print(summary)
columns = df.columns.tolist()
print(columns)
sns.pairplot(df)
plt.show()
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()
# Identify the dependent and independent variables
dependent_var = 'Price'
independent_vars = df.select_dtypes(include=['number']).columns.tolist()
independent_vars.remove(dependent_var)

print("Dependent Variable:", dependent_var)
print("Independent Variables:", independent_vars)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# 90%     -117.250000     38.480000           46.000000   4651.500000
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X = np.random.rand(100, 1)
Y = 3 * X.squeeze() + np.random.randn(100)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, Y_train)
import scipy.stats as stats
intercept = model.intercept_
slope = model.coef_[0]
Y_pred = model.predict(X_test)
cdf_values = stats.norm.cdf(Y_pred, np.mean(Y_pred), np.std(Y_pred))
print(f"Intercept: {intercept}")
print(f"Slope: {slope}")
print(f"CDF of the predictions: {cdf_values}")
# Out:
# Intercept: 0.05119766837112549
# Slope: 3.193811618727873
# CDF of the predictions: [0.69830936 0.07498042 0.35982652 0.50822068 0.94677925 0.43509127
#  0.7658001  0.5805856  0.20433654 0.13285912 0.92818823 0.1460128
#  0.92553259 0.29847919 0.29765205 0.91134406 0.09669954 0.84920276
#  0.08730514 0.61872388]
